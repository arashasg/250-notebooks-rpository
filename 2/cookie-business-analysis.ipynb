# %%
# importing libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#importing data
data = pd.read_excel('../input/cookie-business/cookie_business.xlsx')

# %%
data.head()

# %%
#finding out the shape of the data using "shape" variable: Output (rows, columns)
data.shape

# %%
#Printing all the columns present in data
data.columns

# %%
#Printing datatypes of different columns
data.dtypes

# %%
#To convert Postcode from integer to Object data type
data['Customer ID']=data['Customer ID'].astype(str)

# %%
#Printing the updated datatypes
data.dtypes

# %%
# list of columns
select_columns = ['Postcode','Age Group', 'Age', 'Gender', 'Favourite Cookie','Cookies bought each week']

# dataframe with specific columns
data[select_columns].head()

# %%
# get the summary
data.describe()

# %%
#Checking for the missing values in the data
data.isna().sum()

# %% [markdown]
#     ** Fortunately, there is no missing values in the dataset.

# %%
#Calculate the average 
pd.pivot_table(data, index=['Favourite Cookie'], values="Cookies bought each week", aggfunc= ['count'])

# %% [markdown]
#     ** Most popular,high in demand is Macadamia and Choc Chip cookies.

# %%
#Cross table between Gender and Favourite Cookies
pd.crosstab(data['Gender'], data['Favourite Cookie'])

# %% [markdown]
#     ** Female buyers are more in account than male.

# %%
#Cross table between Gender and Favourite Cookies
pd.crosstab(data['Age Group'], data['Favourite Cookie'])

# %% [markdown]
#      ** This above table depicts, looks Lana's cookies is popular among teens and twenties.

# %%
# Analyze the spread of the "Cookies bought each week" column
sns.distplot(data["Cookies bought each week"], kde = True);

# %%
data["Cookies bought each week"].skew()

# %% [markdown]
#     ** This Density plot defines clearly that cookies bought each week is right skewed.
#     Mode < Median < Mean. The distribution od data is non-normal.

# %%
data.median()

# %%
data["Cookies bought each week"].mode()

# %%
data.mean()

# %%
data["Cookies bought each week"].std()

# %% [markdown]
#     Mode < Median < Mean. The distribution od data is non-normal.

# %%
# What are the different types of Cookies

plot = sns.countplot(x = "Favourite Cookie", data = data)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40);

# %% [markdown]
#        **Graphical representation of favourite cookies and its demand each week. This shows Macadamia and Choc-Chip is high in demand.

# %%
#Counts the number of cookies
data['Favourite Cookie'].value_counts()

# %%
plot = sns.countplot(x = "Age Group", data = data)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40);

# %% [markdown]
#       ***Popularity of cookies are among teens and twenties.

# %%
#EDA Age Group
data['Age Group'].value_counts()

# %%
#Ploting Gender
plot = sns.countplot(x = "Gender", data = data)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40);

# %% [markdown]
#     ***Female customers are more than male. i.e 58.70% F and 41.30% M

# %%
#Counts the number of Male and Female buyers
data['Gender'].value_counts()

# %%
#Ploting Postcode
plot = sns.countplot(x = "Postcode", data = data)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40);

# %%
#Counts Postcodes
data['Postcode'].value_counts()

# %% [markdown]
#     *** Most of the buyers hails from Postcode 2000, rest of the areas does minor sales in comparison to 2000 postcode of Australia region.

# %%
fig, axs = plt.subplots(figsize = (10,10))
sns.boxplot(x = "Favourite Cookie", y = "Cookies bought each week", data = data, ax=axs, hue='Favourite Cookie');

# %% [markdown]
#     *** This above Boxplot shows outliers are present. There is may be sudden sales of Product: Choc Chip and Macadamia within a week.
#     Granola cookies looks promising. So, may be in future sales pick up.
#
#     Mint and Triple Choc sales are almost same.
#     Salted Caramel is least in sales. Seems customers doesn't like this flavor.

# %%
#Correlation
data["Age"].corr(data["Cookies bought each week"])
data['Postcode'].corr(data['Cookies bought each week'])
data['Age'].corr(data['Postcode'])

# %%
data.corr()

# %% [markdown]
#     *** Strange but Age and Postcode are negatively correlated. This correlation looks strong in comparison to other factors.
#
#     Age and Cookies bought each week shows negatively weak relation but still matter of doubt.
#
#     Postcode and Cookies bought each week show weak but positive relation. But as per the sales looks Lana's cookies are not famous or marketing is not strong other than 2000 Postcode. So, there is drastic down in sales in other Postcodes.
#     So, sales within the close proximity of Postcode 2000 is there.

# %%
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#Scatterplot between Age and Cookies bought each week
plot = sns.regplot(x = "Age", y = "Cookies bought each week", data = data)

# %% [markdown]
#        *** This scatter plot depicts w.r.t age, sales gets affected.

# %%
#Scatterplot between Age and Postcode
plot = sns.regplot(x = "Postcode", y = "Age", data = data)

# %% [markdown]
#     *** Age and Postcode correlation is seen in the above scatterplot. close proximity to Postcode 2000, sales is seen mainly. Rest of the areas shows low sales.

# %%
#Scatterplot between Postcode and Cookies bought each week
plot = sns.regplot(x = "Postcode", y = "Cookies bought each week", data = data)

# %% [markdown]
#     ** Relation shows positive correlation. But, If you carefully examine then this relation is strong upto certain level. i,e close to Postcode 2000. Beyond 2331, sales reduced drastically.

# %%
#Bar-plot
fig, axs = plt.subplots(figsize = (15,15))
sns.countplot(x = "Postcode", data = data, ax=axs, hue = "Age Group");

# %% [markdown]
#     *** 10-19: 2000, 2321, 2331 , --- 2332, 2333, 2344, 2347, 2444
#         20-29: 2000, 2010 , ---- 2001, 2019, 2022, 2093, 2210, 2211
#         30-39: 2000, ---- 2010, 2093, 2222, 2763, 2873
#         40-49: 2000, 2022, ---- 2210, 2321
#         50-59: 2000, 2010, ---- 2030
#         60-69: 2000
#
#        Quite evident from the chart, Age is the major factor in sales. Teens and Twenties and even in thirtees customers are cookie lovers.
#        Highest sales are in 2000 Postcode and in close proximity.

# %%
#Bar-plot
fig, axs = plt.subplots(figsize = (15,15))
sns.countplot(x = "Favourite Cookie", data = data, ax=axs, hue = "Age Group");

# %% [markdown]
#     *** 10-19: Choc- Chip , --- Macadamia, Triple Choc, Granola
#         20-29: Macadamia , ---- Choc-Chip, Granola
#         30-39: Macadamia , ---- Choc-Chip
#         40-49: Choc-Chip and Triple Choc, --- Granola and Mint
#         50-59: Choc-Chip
#         60-69: Macadamia

# %%
#Bar-plot
fig, axs = plt.subplots(figsize = (15,15))
sns.countplot(x = "Favourite Cookie", data = data, ax=axs, hue = "Gender");

# %% [markdown]
#     *** Choc Chip and Macadamia cookies are the favourite cookies among both male and female.
#     Females don't like Salted Caramel, it seems so.
#     Mint flavour is the least bought by male customers.
#     While, caramel flavour cookies are equally favourite for male and female.
#
#     Choc flavours are popular among females than males.

# %% [markdown]
# #Task: Questions to Deal with
#
# 1. What demographic characteristics are provided in the dataset?
# --> Age, Age Group, Postcode, Favourite Cookie and Gender are the demographic characteristics provided in the dataset.
# 2. Which demographic group buys the most cookies?
# --> 1.	Age wise groups: Then among teens, twenties, and thirties buy most of the cookies.
#     2.	If we segregate w.r.t Gender, then female buyers are more than male.
# 3. What is the most popular type of cookie?
# --> Macadamia and Choc-Chip are the two most popular type pf cookies among both male and female.
#
# 4. What types of cookie should Lana sell and why?
# --> On Analysing Lana’s historic dataset, most popular cookies are Macadamia and Choc-Chip. Along with that, Granola is slowly coming in demand equally     among male and female.
#     According to dataset, it seems female customers are approx. 58.7% ~ 60%.  And they like Triple Choc and Mint flavour too. Even Mint sales is much       better than Salted Caramel.
#     She must continue selling cookies except Salted Caramel which has least performance.
#
# 5. Which demographics should she target?
# --> Target customers are Female, Postcode 2000 and the nearby proximity/area, age group lies between twenties to thirties.
#     Age and Postcode is negatively shows moderate level of correlation.

# %% [markdown]
# Conclusion:
